# %% [markdown]
# # **Feature Scaling** and **Encoding of Data** in Machine Learning

# %% [markdown]
# ## **Encoding Data in Machine Learning**
#
# - In machine learning, **encoding** means **converting categorical (non-numeric) data into numeric form** so that algorithm can process it.
# - Most ML models (like Linear Regression, SVM, etc) work only with **numerical data**, so encoding transforms **text or categorical labels** into numbers with numbers without losing inportant information.
# - **Why Encoding is Needed**: To get faster processing.

# %% [markdown]
# ## **Types of Data Requiring Encoding**:
#
# - **Nominal Data**: without any ordering
# - **Ordinal Data**: with some ordering

# %% [markdown]
# ### A. **Label Encoding in Python**: Converts categorical data into labelled data

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
data=['Small','Medium','Large']
encoded = encoder.fit_transform(data)
print(encoded)
# Out:
# [2 1 0]

# %% [markdown]
# ### B. **One-Hot Encoding**: Converts to Binary columns (0/1)

# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

df = pd.DataFrame({ 'Color': ['Red', 'Blue', 'Green'] })
encoder = OneHotEncoder(sparse_output=False)
encoded = encoder.fit_transform(df[['Color']])
print(encoded)
# Out:
# [[0. 0. 1.]
#  [1. 0. 0.]
#  [0. 1. 0.]]

# %% [markdown]
# ### C. **Ordinal Encoding**: Converts categorical data into labelled data with an ordering.

# %%
from sklearn.preprocessing import OrdinalEncoder
import pandas as pd

df = pd.DataFrame({ 'Rating': ['Poor', 'Average', 'Good'] })
encoder = OrdinalEncoder(categories=[['Poor', 'Average', 'Good']])
encoded = encoder.fit_transform(df)
print(encoded)
# Out:
# [[0.]
#  [1.]
#  [2.]]

# %% [markdown]
# ### D. **Binary Encoding**: Converts into **binary digits** and splits into columns

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in e:\class notes\python training\training\lib\site-packages (2.9.0)
# Requirement already satisfied: numpy>=1.14.0 in e:\class notes\python training\training\lib\site-packages (from category_encoders) (2.3.2)
# Requirement already satisfied: pandas>=1.0.5 in e:\class notes\python training\training\lib\site-packages (from category_encoders) (2.3.2)
# Requirement already satisfied: patsy>=0.5.1 in e:\class notes\python training\training\lib\site-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in e:\class notes\python training\training\lib\site-packages (from category_encoders) (1.7.1)
# Requirement already satisfied: scipy>=1.0.0 in e:\class notes\python training\training\lib\site-packages (from category_encoders) (1.16.1)
# Requirement already satisfied: statsmodels>=0.9.0 in e:\class notes\python training\training\lib\site-packages (from category_encoders) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\class notes\python training\training\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\class notes\python training\training\lib\site-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\class notes\python training\training\lib\site-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in e:\class notes\python training\training\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\class notes\python training\training\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in e:\class notes\python training\training\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (25.0)
# Requirement already satisfied: six>=1.5 in e:\class notes\python training\training\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import category_encoders as ce
import pandas as pd

df = pd.DataFrame({ 'City': ['Delhi', 'Mumbai', 'Kolkata'] })
encoder = ce.BinaryEncoder(cols=['City'])
encoded = encoder.fit_transform(df)
print(encoded)
# Out:
#    City_0  City_1
# 0       0       1
# 1       1       0
# 2       1       1

# %% [markdown]
# ### E. **Target Encoding**: Replaces the **category** with the **mean of the target variable** for that category

# %%
import category_encoders as ce
import pandas as pd

df = pd.DataFrame({ 
    'City': ['Delhi', 'Mumbai', 'Delhi', 'Kolkata', 'Mumbai'],
    'House_Price': [10.5, 12.0, 11.0, 8.0, 13.0]
})

# Apply target Encoder
encoder = ce.TargetEncoder(cols=['City'])
df['City_Encoded'] = encoder.fit_transform(df['City'], df['House_Price'])
print(encoded)
# Out:
#    City_0  City_1
# 0       0       1
# 1       1       0
# 2       1       1
